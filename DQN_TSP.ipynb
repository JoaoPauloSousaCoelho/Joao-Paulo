# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoPauloSousaCoelho/Joao-Paulo/blob/master/DQN_TSP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: build a bayesian optimization algorithm. Considering to test different neural  architecture. Please, test in differents instances and calculate the gap (ratio between best distance and the optimum distance of the instance). Please save the results (generating a csv file) (distances and gaps found, values of hiperparameters and name of instances)

# --- Data Collection and CSV Saving ---

# Store results from Bayesian Optimization runs
results_list = []

@use_named_args(space)
def objective(**params):
    """
    Objective function for Bayesian Optimization.
    Evaluates performance across different TSP instances and stores results.
    """
    print("\nEvaluating hyperparameters:")
    print(params)

    instance_scores = {}
    for instance_name, cities_coords in TSP_INSTANCES.items():
        print(f"  Evaluating on instance: {instance_name}")
        env = TSPEnvironment(cities_coords)
        state_input_shape = env.num_cities + env.num_cities + (env.num_cities * 2)
        action_size = env.num_cities
        optimal_distance = 22 if instance_name == "eil7" else None # Define optimal distances for known instances

        try:
            agent = DQNAgent(
                state_size=state_input_shape,
                action_size=action_size,
                learning_rate=params['learning_rate'],
                gamma=params['gamma'],
                epsilon_start=1.0,
                epsilon_end=params['epsilon_end'],
                epsilon_decay_rate=params['epsilon_decay_rate'],
                replay_buffer_size=params['replay_buffer_size'],
                batch_size=params['batch_size'],
                target_update_freq=params['target_update_freq'],
                n_hidden_layers=params['n_hidden_layers'],
                n_neurons=params['n_neurons']
            )

            instance_avg_tour_length = train_dqn_for_optimization(env, agent, num_episodes=200)

            agent.cleanup()
            del agent
            gc.collect()
            tf.keras.backend.clear_session()
            gc.collect()

            instance_scores[instance_name] = instance_avg_tour_length
            print(f"    Instance {instance_name} average tour length: {instance_avg_tour_length:.2f}")

        except Exception as e:
            print(f"    Training failed for instance {instance_name} with params {params}: {e}")
            instance_scores[instance_name] = 10000 # Penalty for failure

    # Store results for this set of hyperparameters
    result_entry = params.copy()
    result_entry['avg_score_across_instances'] = np.mean(list(instance_scores.values()))

    # Calculate and store gap for each instance (if optimal is known)
    for instance_name, avg_dist in instance_scores.items():
        result_entry[f'{instance_name}_distance'] = avg_dist
        if instance_name == "eil7" and 22 is not None: # Check if optimal is known for this instance
             result_entry[f'{instance_name}_gap'] = (avg_dist - 22) / 22 if 22 > 0 else float('inf')
        else:
             result_entry[f'{instance_name}_gap'] = None # Gap is None if optimal is unknown

    results_list.append(result_entry)

    return result_entry['avg_score_across_instances']

# --- Run Bayesian Optimization and Collect Results ---

print("Starting Bayesian Optimization with multi-instance evaluation and data collection...")

res_gp = gp_minimize(
    objective,
    space,
    n_calls=100,
    n_initial_points=20,
    random_state=42,
    verbose=True,
    n_jobs=1
)

print("\nBayesian Optimization finished.")
print(f"Best score (minimum average tour length across instances): {res_gp.fun:.2f}")
print("Best hyperparameters found:")
best_params = dict(zip([param.name for param in space], res_gp.x))
print(best_params)

# --- Save Results to CSV ---

print("\nSaving results to CSV...")

# Convert the list of results (dictionaries) into a pandas DataFrame
results_df = pd.DataFrame(results_list)

# Define the filename
csv_filename = "bayesian_optimization_results.csv"

# Save the DataFrame to a CSV file
results_df.to_csv(csv_filename, index=False)

print(f"Results saved to {csv_filename}")

# Optional: Display the first few rows of the results DataFrame
print("\nResults DataFrame Head:")
print(results_df.head())
# Out:
# Starting Bayesian Optimization with multi-instance evaluation and data collection...
# Iteration No: 1 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.002452612631133679, 'gamma': 0.8365035231833666, 'epsilon_end': 0.15814129005182623, 'epsilon_decay_rate': 0.9979245657739378, 'replay_buffer_size': np.int64(5012), 'batch_size': np.int64(83), 'target_update_freq': np.int64(165), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(91)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 213.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 33284.00
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 66.8045
# Function value obtained: 16748.5000
# Current minimum: 16748.5000
# Iteration No: 2 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.0008967376801947966, 'gamma': 0.811225904226393, 'epsilon_end': 0.14717976673069674, 'epsilon_decay_rate': 0.9995989082741772, 'replay_buffer_size': np.int64(1007), 'batch_size': np.int64(255), 'target_update_freq': np.int64(204), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(65)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 173.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 30381.00
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 61.8699
# Function value obtained: 15277.0000
# Current minimum: 15277.0000
# Iteration No: 3 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 1.1727009450102244e-05, 'gamma': 0.9044301573914195, 'epsilon_end': 0.08597358462589856, 'epsilon_decay_rate': 0.9952286617497467, 'replay_buffer_size': np.int64(9764), 'batch_size': np.int64(109), 'target_update_freq': np.int64(73), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(137)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 199.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 31759.00
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 65.7052
# Function value obtained: 15979.0000
# Current minimum: 15277.0000
# Iteration No: 4 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.008906204386161689, 'gamma': 0.8928858157563481, 'epsilon_end': 0.17338867727990095, 'epsilon_decay_rate': 0.9983335069390801, 'replay_buffer_size': np.int64(5054), 'batch_size': np.int64(67), 'target_update_freq': np.int64(286), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(138)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 193.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 31829.00
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 66.6872
# Function value obtained: 16011.0000
# Current minimum: 15277.0000
# Iteration No: 5 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 1.1166029133981341e-05, 'gamma': 0.8459478712988077, 'epsilon_end': 0.05579483854494224, 'epsilon_decay_rate': 0.9983479912422447, 'replay_buffer_size': np.int64(6490), 'batch_size': np.int64(224), 'target_update_freq': np.int64(93), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(99)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 203.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 30909.00
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 63.8802
# Function value obtained: 15556.0000
# Current minimum: 15277.0000
# Iteration No: 6 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.001845373292661596, 'gamma': 0.8846060190237577, 'epsilon_end': 0.04950891594495589, 'epsilon_decay_rate': 0.997781731606318, 'replay_buffer_size': np.int64(1282), 'batch_size': np.int64(226), 'target_update_freq': np.int64(162), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(242)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 186.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 32890.00
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 69.2598
# Function value obtained: 16538.0000
# Current minimum: 15277.0000
# Iteration No: 7 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.001519903403705409, 'gamma': 0.8649816129923613, 'epsilon_end': 0.1183843551370259, 'epsilon_decay_rate': 0.9975520878741265, 'replay_buffer_size': np.int64(9651), 'batch_size': np.int64(226), 'target_update_freq': np.int64(237), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(177)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 145.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 32817.00
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 67.6033
# Function value obtained: 16481.0000
# Current minimum: 15277.0000
# Iteration No: 8 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.007866216981266856, 'gamma': 0.9207998152896503, 'epsilon_end': 0.062439844584283255, 'epsilon_decay_rate': 0.99645174017795, 'replay_buffer_size': np.int64(2487), 'batch_size': np.int64(67), 'target_update_freq': np.int64(156), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(120)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 157.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 29262.00
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 65.2392
# Function value obtained: 14709.5000
# Current minimum: 14709.5000
# Iteration No: 9 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 1.1021468611551664e-05, 'gamma': 0.8395696384136723, 'epsilon_end': 0.14515497102224353, 'epsilon_decay_rate': 0.998871860148603, 'replay_buffer_size': np.int64(6454), 'batch_size': np.int64(242), 'target_update_freq': np.int64(213), 'n_hidden_layers': np.int64(3), 'n_neurons': np.int64(227)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 196.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 31890.00
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 85.5830
# Function value obtained: 16043.0000
# Current minimum: 14709.5000
# Iteration No: 10 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.00022302421654007715, 'gamma': 0.8189866131815919, 'epsilon_end': 0.08045546791767061, 'epsilon_decay_rate': 0.9982773221380516, 'replay_buffer_size': np.int64(6993), 'batch_size': np.int64(178), 'target_update_freq': np.int64(119), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(138)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 169.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 33700.00
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 66.7199
# Function value obtained: 16934.5000
# Current minimum: 14709.5000
# Iteration No: 11 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.008225007188121396, 'gamma': 0.9689338510289507, 'epsilon_end': 0.14712860902132593, 'epsilon_decay_rate': 0.9961563261067699, 'replay_buffer_size': np.int64(3305), 'batch_size': np.int64(72), 'target_update_freq': np.int64(228), 'n_hidden_layers': np.int64(1), 'n_neurons': np.int64(148)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 189.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 31708.00
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 51.3509
# Function value obtained: 15948.5000
# Current minimum: 14709.5000
# Iteration No: 12 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 4.028632082859626e-05, 'gamma': 0.9782569555390304, 'epsilon_end': 0.10032034240460125, 'epsilon_decay_rate': 0.9977600503026843, 'replay_buffer_size': np.int64(7260), 'batch_size': np.int64(91), 'target_update_freq': np.int64(201), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(103)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 193.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 30014.00
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 64.6552
# Function value obtained: 15103.5000
# Current minimum: 14709.5000
# Iteration No: 13 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.006738460883888436, 'gamma': 0.9191742278312187, 'epsilon_end': 0.1420091372775439, 'epsilon_decay_rate': 0.9993142924111748, 'replay_buffer_size': np.int64(6619), 'batch_size': np.int64(121), 'target_update_freq': np.int64(76), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(106)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 204.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 30441.00
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 64.9694
# Function value obtained: 15322.5000
# Current minimum: 14709.5000
# Iteration No: 14 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.00017763553307102736, 'gamma': 0.9757727715248549, 'epsilon_end': 0.07162555399100207, 'epsilon_decay_rate': 0.9955982309780333, 'replay_buffer_size': np.int64(4207), 'batch_size': np.int64(238), 'target_update_freq': np.int64(118), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(64)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 202.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 33051.00
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 61.5710
# Function value obtained: 16626.5000
# Current minimum: 14709.5000
# Iteration No: 15 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.00011421064100297747, 'gamma': 0.8606514703734478, 'epsilon_end': 0.04128461209715894, 'epsilon_decay_rate': 0.9976170381549396, 'replay_buffer_size': np.int64(5363), 'batch_size': np.int64(197), 'target_update_freq': np.int64(117), 'n_hidden_layers': np.int64(1), 'n_neurons': np.int64(96)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 223.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 30406.00
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 48.6717
# Function value obtained: 15314.5000
# Current minimum: 14709.5000
# Iteration No: 16 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 4.532028775764877e-05, 'gamma': 0.9110622984014509, 'epsilon_end': 0.08672887250102777, 'epsilon_decay_rate': 0.995317972010834, 'replay_buffer_size': np.int64(3285), 'batch_size': np.int64(111), 'target_update_freq': np.int64(224), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(92)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 205.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 28977.00
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 63.4251
# Function value obtained: 14591.0000
# Current minimum: 14591.0000
# Iteration No: 17 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.00984512999986813, 'gamma': 0.8530894218407817, 'epsilon_end': 0.1955568416082041, 'epsilon_decay_rate': 0.9970140813652594, 'replay_buffer_size': np.int64(1297), 'batch_size': np.int64(130), 'target_update_freq': np.int64(209), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(166)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 179.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 32506.00
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 67.9892
# Function value obtained: 16342.5000
# Current minimum: 14591.0000
# Iteration No: 18 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.0002204699957458677, 'gamma': 0.9100257247251943, 'epsilon_end': 0.12261237753708479, 'epsilon_decay_rate': 0.9953961812990303, 'replay_buffer_size': np.int64(4327), 'batch_size': np.int64(110), 'target_update_freq': np.int64(251), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(253)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 231.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 29419.00
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 69.6261
# Function value obtained: 14825.0000
# Current minimum: 14591.0000
# Iteration No: 19 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.00015720752387932225, 'gamma': 0.9624699427706574, 'epsilon_end': 0.16168557374706477, 'epsilon_decay_rate': 0.9957385159654306, 'replay_buffer_size': np.int64(5574), 'batch_size': np.int64(198), 'target_update_freq': np.int64(265), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(106)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 196.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 32630.00
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 65.0891
# Function value obtained: 16413.0000
# Current minimum: 14591.0000
# Iteration No: 20 started. Evaluating function at random point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.0013597172189103752, 'gamma': 0.9610907081818034, 'epsilon_end': 0.07624653758542858, 'epsilon_decay_rate': 0.995471265100348, 'replay_buffer_size': np.int64(9465), 'batch_size': np.int64(140), 'target_update_freq': np.int64(179), 'n_hidden_layers': np.int64(3), 'n_neurons': np.int64(194)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 204.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 29151.00
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 85.8292
# Function value obtained: 14677.5000
# Current minimum: 14591.0000
# Iteration No: 21 started. Searching for the next optimal point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.00032074947408570315, 'gamma': 0.9113818354103858, 'epsilon_end': 0.11107997428334954, 'epsilon_decay_rate': 0.9962550175328444, 'replay_buffer_size': np.int64(3042), 'batch_size': np.int64(111), 'target_update_freq': np.int64(106), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(68)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 204.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 30923.00
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 62.5737
# Function value obtained: 15563.5000
# Current minimum: 14591.0000
# Iteration No: 22 started. Searching for the next optimal point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.0001747306427505015, 'gamma': 0.929082104966928, 'epsilon_end': 0.09059977559178903, 'epsilon_decay_rate': 0.9957172434283184, 'replay_buffer_size': np.int64(3857), 'batch_size': np.int64(96), 'target_update_freq': np.int64(202), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(68)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 171.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 32251.00
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 63.7428
# Function value obtained: 16211.0000
# Current minimum: 14591.0000
# Iteration No: 23 started. Searching for the next optimal point.
#
# Evaluating hyperparameters:
# {'learning_rate': 0.001399855164189368, 'gamma': 0.9112369685489192, 'epsilon_end': 0.10578660405523892, 'epsilon_decay_rate': 0.9960600245460723, 'replay_buffer_size': np.int64(5229), 'batch_size': np.int64(111), 'target_update_freq': np.int64(221), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(220)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 212.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 33184.00
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 67.0903
# Function value obtained: 16698.0000
# Current minimum: 14591.0000
# Iteration No: 24 started. Searching for the next optimal point.
#
# Evaluating hyperparameters:
# {'learning_rate': 1.172555282859561e-05, 'gamma': 0.9142527235680613, 'epsilon_end': 0.08599178496268747, 'epsilon_decay_rate': 0.9953224019992593, 'replay_buffer_size': np.int64(4746), 'batch_size': np.int64(181), 'target_update_freq': np.int64(228), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(92)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 204.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 33017.00
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 65.3288
# Function value obtained: 16610.5000
# Current minimum: 14591.0000
# Iteration No: 25 started. Searching for the next optimal point.
#
# Evaluating hyperparameters:
# {'learning_rate': 4.459429897156504e-05, 'gamma': 0.9313029680040876, 'epsilon_end': 0.11682883060821844, 'epsilon_decay_rate': 0.996169641863942, 'replay_buffer_size': np.int64(1225), 'batch_size': np.int64(226), 'target_update_freq': np.int64(211), 'n_hidden_layers': np.int64(3), 'n_neurons': np.int64(100)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 179.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 30723.00
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 80.2711
# Function value obtained: 15451.0000
# Current minimum: 14591.0000
# Iteration No: 26 started. Searching for the next optimal point.
#
# Evaluating hyperparameters:
# {'learning_rate': 5.438558447698364e-05, 'gamma': 0.8976530386610778, 'epsilon_end': 0.14390277174548088, 'epsilon_decay_rate': 0.9956075148796366, 'replay_buffer_size': np.int64(4696), 'batch_size': np.int64(115), 'target_update_freq': np.int64(203), 'n_hidden_layers': np.int64(3), 'n_neurons': np.int64(104)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 200.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 31682.00
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 78.4895
# Function value obtained: 15941.0000
# Current minimum: 14591.0000
# Iteration No: 27 started. Searching for the next optimal point.
#
# Evaluating hyperparameters:
# {'learning_rate': 4.501115942415011e-05, 'gamma': 0.911592665034628, 'epsilon_end': 0.15728338306129272, 'epsilon_decay_rate': 0.9970880168428606, 'replay_buffer_size': np.int64(6087), 'batch_size': np.int64(149), 'target_update_freq': np.int64(223), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(92)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 195.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 31277.00
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 65.9334
# Function value obtained: 15736.0000
# Current minimum: 14591.0000
# Iteration No: 28 started. Searching for the next optimal point.
#
# Evaluating hyperparameters:
# {'learning_rate': 4.5334449598549644e-05, 'gamma': 0.8959252619842291, 'epsilon_end': 0.08694327119776021, 'epsilon_decay_rate': 0.9957902126001921, 'replay_buffer_size': np.int64(5633), 'batch_size': np.int64(172), 'target_update_freq': np.int64(224), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(223)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 187.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 31184.00
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 66.4341
# Function value obtained: 15685.5000
# Current minimum: 14591.0000
# Iteration No: 29 started. Searching for the next optimal point.
#
# Evaluating hyperparameters:
# {'learning_rate': 4.529331952759788e-05, 'gamma': 0.9034076696677249, 'epsilon_end': 0.08686732220897014, 'epsilon_decay_rate': 0.9981964448708169, 'replay_buffer_size': np.int64(3224), 'batch_size': np.int64(66), 'target_update_freq': np.int64(224), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(90)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 164.00
#   Evaluating on instance: berlin52
#     Instance berlin52 average tour length: 30319.00
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 64.3362
# Function value obtained: 15241.5000
# Current minimum: 14591.0000
# Iteration No: 30 started. Searching for the next optimal point.
#
# Evaluating hyperparameters:
# {'learning_rate': 4.5316030826533035e-05, 'gamma': 0.9114692082965405, 'epsilon_end': 0.08628863219687936, 'epsilon_decay_rate': 0.9951142046352905, 'replay_buffer_size': np.int64(6213), 'batch_size': np.int64(139), 'target_update_freq': np.int64(224), 'n_hidden_layers': np.int64(2), 'n_neurons': np.int64(87)}
#   Evaluating on instance: eil7
#     Instance eil7 average tour length: 212.00
#   Evaluating on instance: berlin52
